# %%
import nibabel as nib
import numpy as np
import matplotlib.pyplot as plt

# %%
test_load = nib.load('/home/jack/Documents/case/Case_00773.nii.gz')
test_load.shape
# Out:
# (512, 512, 48)

# %%
print(test_load.header)
# Out:
# <class 'nibabel.nifti1.Nifti1Header'> object, endian='<'
# sizeof_hdr      : 348
# data_type       : b''
# db_name         : b''
# extents         : 0
# session_error   : 0
# regular         : b'r'
# dim_info        : 0
# dim             : [  3 512 512  48   1   1   1   1]
# intent_p1       : 0.0
# intent_p2       : 0.0
# intent_p3       : 0.0
# intent_code     : none
# datatype        : uint16
# bitpix          : 16
# slice_start     : 0
# pixdim          : [1.       0.976562 0.976562 5.       0.       0.       0.       0.      ]
# vox_offset      : 0.0
# scl_slope       : nan
# scl_inter       : nan
# slice_end       : 0
# slice_code      : unknown
# xyzt_units      : 2
# cal_max         : 0.0
# cal_min         : 0.0
# slice_duration  : 0.0
# toffset         : 0.0
# glmax           : 0
# glmin           : 0
# descrip         : b''
# aux_file        : b''
# qform_code      : aligned
# sform_code      : scanner
# quatern_b       : 0.0
# quatern_c       : 0.0
# quatern_d       : 0.0
# ...

# %%
test = test_load.dataobj[:,:,1]
plt.imshow(test)
plt.show()

# %%
k = 0
for i in range(5):
    plt.subplot(5, 5,i + 1)
    plt.imshow(test_load.dataobj[:,:,k])
    k = k+i
    plt.gcf().set_size_inches(10, 10)
plt.show()

# %%
from skimage.util import montage

# 顯示所有切面
fig, ax = plt.subplots(1, 1, figsize = (20, 20))
ax.imshow(montage(test_load.dataobj))
# ax.imshow(montage(test_load.dataobj), cmap ='gray')
